# %%
import pandas as pd
import xgboost as xgb

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, root_mean_squared_error, r2_score

# %%
study = pd.read_csv('titanic_study_data.csv')
answer = pd.read_csv('titanic_answer_data.csv')

# %%
study_train, study_test, answer_train, answer_test = train_test_split(study, answer, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
study_train = scaler.fit_transform(study_train)
study_test = scaler.transform(study_test)

# %%
model = xgb.XGBRFRegressor(n_estinator = 100, learning_rate=0.1, max_depth=3, random_state=42)
model.fit(study_train, answer_train)
# Out:
# d:\Program\Anaconda\envs\machine_learning\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:05:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estinator" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.1, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=3, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_estinator=100,
#                n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', ...)

# %%
predict = model.predict(study_test)

# %%
predict
# Out:
# array([0.3540238 , 0.3540217 , 0.3512135 , 0.4337489 , 0.3991557 ,
#        0.43481386, 0.39697766, 0.3520641 , 0.39697766, 0.431784  ,
#        0.3718018 , 0.35060441, 0.3533058 , 0.35195944, 0.35412025,
#        0.43255687, 0.37153256, 0.39652365, 0.35412025, 0.36634982,
#        0.3512135 , 0.3654534 , 0.39263386, 0.3512135 , 0.3519351 ,
#        0.35555917, 0.36560282, 0.35412025, 0.36498165, 0.39309978,
#        0.3512135 , 0.3935538 , 0.36705503, 0.39393765, 0.3512135 ,
#        0.35308102, 0.36634982, 0.39697766, 0.4328019 , 0.3512135 ,
#        0.36351612, 0.3510666 , 0.3512135 , 0.35177395, 0.3983483 ,
#        0.35532093, 0.3512135 , 0.3512135 , 0.3510666 , 0.3713622 ,
#        0.3996438 , 0.43474826, 0.35455954, 0.38056865, 0.3505863 ,
#        0.43425187, 0.3540217 , 0.43401766, 0.43216786, 0.39652365,
#        0.3512135 , 0.43252546, 0.43234858, 0.36124328, 0.35177395,
#        0.431731  , 0.3628862 , 0.3512135 , 0.35330224, 0.43497327,
#        0.43187267, 0.43265218, 0.3677427 , 0.43481645, 0.3512135 ,
#        0.3519351 , 0.39657766, 0.431989  , 0.43216786, 0.39550298,
#        0.3549757 , 0.43179917, 0.43481645, 0.35177395, 0.36705503,
#        0.36719733, 0.43504146, 0.43496594, 0.35955623, 0.3512135 ,
#        0.36320543, 0.3533058 , 0.36634982, 0.35177395, 0.3512135 ,
#        0.3512135 , 0.36674905, 0.35060441, 0.43216786, 0.3512135 ,
#        0.36124328, 0.35068634, 0.4346238 , 0.3504575 , 0.3512135 ,
#        0.3512135 , 0.4325536 , 0.36634982, 0.3512135 , 0.36649925,
#        0.4325536 , 0.3512135 , 0.43504146, 0.3654534 , 0.37051383,
#        0.3515036 , 0.36719733, 0.35426968, 0.43193093, 0.35417867,
#        0.35569298, 0.43528977, 0.43497327, 0.4149169 , 0.3512135 ,
#        0.36560282, 0.4325287 , 0.37102574, 0.3991557 , 0.3512135 ,
#        0.39652365, 0.3540238 , 0.35339868, 0.39621994, 0.371682  ,
#        0.3991557 , 0.43528977, 0.3512135 , 0.35060441, 0.39573184,
#        0.3512135 , 0.43234858, 0.35412025, 0.3549088 , 0.3563802 ,
#        0.4325536 , 0.35412025, 0.3540217 , 0.43497464, 0.35060441,
#        0.35235944, 0.3512135 , 0.3512135 , 0.37623134, 0.3512135 ,
#        0.3510666 , 0.36301568, 0.39652365, 0.43234858, 0.3987557 ,
#        0.35235944, 0.3654534 , 0.35412025, 0.43504146, 0.35177395,
#        0.36964026, 0.3540217 , 0.4325536 , 0.3512135 , 0.35068634,
#        0.37059715, 0.43135497, 0.3654534 , 0.3991557 , 0.3510666 ,
#        0.35235944, 0.35336915, 0.43147042, 0.39621994], dtype=float32)

# %%
acc = accuracy_score(answer_test,predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 acc = accuracy_score(answer_test,predict)
#
# File d:\Program\Anaconda\envs\machine_learning\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\Program\Anaconda\envs\machine_learning\Lib\site-packages\sklearn\metrics\_classification.py:231, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     229 xp, _, device = get_namespace_and_device(y_true, y_pred, sample_weight)
#     230 # Compute accuracy for each possible representation
# --> 231 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     232 check_consistent_length(y_true, y_pred, sample_weight)
#     233 if y_type.startswith("multilabel"):
#
# File d:\Program\Anaconda\envs\machine_learning\Lib\site-packages\sklearn\metrics\_classification.py:112, in _check_targets(y_true, y_pred)
#     109     y_type = {"multiclass"}
#     111 if len(y_type) > 1:
# --> 112     raise ValueError(
#     113         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     114             type_true, type_pred
#     115         )
#     116     )
#     118 # We can't have more than one value on y_type => The set is no more needed
#     119 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
acc
# Out:
# 0.5865921787709497

# %%
mse = root_mean_squared_error(answer_test,predict)

# %%
mse
# Out:
# 0.4732222781867384
