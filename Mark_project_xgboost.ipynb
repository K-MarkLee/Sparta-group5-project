# %%
import pandas as pd
import xgboost as xgb

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, root_mean_squared_error, r2_score

# %%
study = pd.read_csv('titanic_study_data.csv')
answer = pd.read_csv('titanic_answer_data.csv')

# %%
study_train, study_test, answer_train, answer_test = train_test_split(study, answer, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
study_train = scaler.fit_transform(study_train)
study_test = scaler.transform(study_test)

# %%
model = xgb.XGBRFRegressor(n_estimators = 100, learning_rate=1.0, max_depth=3, random_state=42)
# model = xgb.XGBRFClassifier(random_state=42)
model.fit(study_train, answer_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=3, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=100, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=42, reg_alpha=None, ...)

# %%
predict = model.predict(study_test)

# %%
predict
# Out:
# array([0.15259756, 0.15257727, 0.12449568, 0.94984925, 0.6039176 ,
#        0.96049756, 0.5821372 , 0.13300142, 0.5821372 , 0.9301999 ,
#        0.33037704, 0.11840449, 0.14541821, 0.13195436, 0.15356272,
#        0.9379287 , 0.32768473, 0.577597  , 0.15356272, 0.27585748,
#        0.12449568, 0.26689363, 0.5386996 , 0.12449568, 0.13171118,
#        0.1679529 , 0.26838803, 0.15356272, 0.2621806 , 0.54335874,
#        0.12449568, 0.547899  , 0.2829096 , 0.5517374 , 0.12449568,
#        0.14316987, 0.27585748, 0.5821372 , 0.9403786 , 0.12449568,
#        0.24752097, 0.12302648, 0.12449568, 0.13009949, 0.59584355,
#        0.16556971, 0.12449568, 0.12449568, 0.12302648, 0.32598123,
#        0.6087985 , 0.9598421 , 0.15795626, 0.41804677, 0.11822277,
#        0.9548783 , 0.15257727, 0.95253664, 0.93403816, 0.577597  ,
#        0.12449568, 0.9376147 , 0.9358455 , 0.22479215, 0.13009949,
#        0.92966944, 0.24122179, 0.12449568, 0.14538203, 0.96209204,
#        0.9310863 , 0.9388835 , 0.28978616, 0.96052396, 0.12449568,
#        0.13171118, 0.5781373 , 0.93225014, 0.93403816, 0.56739086,
#        0.16211735, 0.9303513 , 0.96052396, 0.13009949, 0.2829096 ,
#        0.28433296, 0.9627739 , 0.96201867, 0.20792162, 0.12449568,
#        0.24441569, 0.14541821, 0.27585748, 0.13009949, 0.12449568,
#        0.12449568, 0.27984974, 0.11840449, 0.93403816, 0.12449568,
#        0.22479215, 0.11922388, 0.9585976 , 0.1169353 , 0.12449568,
#        0.12449568, 0.9378957 , 0.27585748, 0.12449568, 0.2773519 ,
#        0.9378957 , 0.12449568, 0.9627739 , 0.26689363, 0.3174974 ,
#        0.12739632, 0.28433296, 0.15505713, 0.9316692 , 0.1541469 ,
#        0.16928957, 0.9652568 , 0.96209204, 0.7615362 , 0.12449568,
#        0.26838803, 0.9376466 , 0.32261664, 0.6039176 , 0.12449568,
#        0.577597  , 0.15259756, 0.1463472 , 0.57456034, 0.32917914,
#        0.6039176 , 0.9652568 , 0.12449568, 0.11840449, 0.56967944,
#        0.12449568, 0.9358455 , 0.15356272, 0.16144834, 0.17616172,
#        0.9378957 , 0.15356272, 0.15257727, 0.96210575, 0.11840449,
#        0.13595437, 0.12449568, 0.12449568, 0.37467372, 0.12449568,
#        0.12302648, 0.24251719, 0.577597  , 0.9358455 , 0.59991753,
#        0.13595437, 0.26689363, 0.15356272, 0.9627739 , 0.13009949,
#        0.30876178, 0.15257727, 0.9378957 , 0.12449568, 0.11922388,
#        0.31833065, 0.92590964, 0.26689363, 0.6039176 , 0.12302648,
#        0.13595437, 0.14605172, 0.92706406, 0.57456034], dtype=float32)

# %%
mse = root_mean_squared_error(answer_test,predict)

# %%
mse
# Out:
# 0.3748768230455687
