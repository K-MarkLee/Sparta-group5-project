# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\kjml\anaconda\envs\myenv\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in d:\kjml\anaconda\envs\myenv\lib\site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in d:\kjml\anaconda\envs\myenv\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: webencodings in d:\kjml\anaconda\envs\myenv\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: colorama in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("netflix_reviews.csv")  # 파일 불러오기

# %%
# 상단 5개 데이터
top_5 = df.head()

# 하단 5개 데이터
bottom_5 = df.tail()

# 컬럼명
columns = df.columns

# 데이터프레임의 shape
shape = df.shape

# 출력
print("상단 5개 데이터:\n",top_5)
print("\n하단 5개 데이터:\n",bottom_5)
print("\n컬럼명:\n",columns)
print("\n데이터프레임의 shape",shape)
# Out:
# 상단 5개 데이터:
#                                 reviewId               userName  \
# 0  65ae4898-8007-47e3-92cd-ba06eac04574  Moosa Sam (Moosa Sam)
# 1  3cc99dd8-81f1-47ce-8b78-18c29719a941           PixEndstar53
# 2  1c639697-a825-4f11-b966-3e7cfb6eb292             JanCan1 GK
# 3  240cfd35-f94d-42d6-b145-154097dd2ce0           Brother Bear
# 4  c568b9f0-7b52-4dad-9b89-f57882014138              Riya Adak
#
#                                              content  score  thumbsUpCount  \
# 0  This App Not Supporting My Device ROG3 Mobile!...      1              0
# 1  I'm getting very tired, you guys keep logging ...      2              0
# 2  One of my go to channels..l was at least 4 mov...      5              0
# 3                      Poor scripts, Violent content      2              0
# 4                                               Good      3              0
#
#      reviewCreatedVersion                   at              appVersion
# 0   8.137.0 build 4 50942  2024-10-23 13:47:33   8.137.0 build 4 50942
# 1   8.137.0 build 4 50942  2024-10-23 13:27:18   8.137.0 build 4 50942
# 2  8.132.2 build 18 50846  2024-10-23 13:26:51  8.132.2 build 18 50846
# 3                     NaN  2024-10-23 13:19:59                     NaN
# 4   8.137.0 build 4 50942  2024-10-23 13:16:59   8.137.0 build 4 50942
#
# 하단 5개 데이터:
#                                      reviewId       userName  \
# 117287  a760ead9-e7aa-4ed1-a651-5c37c3600dac  A Google user
# 117288  4957f9e7-d7f4-4a52-9764-031cebcac83f   Captain Jeoy
# 117289  9acf7586-7abf-4b50-8c50-3ede3b2a42c4       Suryansh
# 117290  32870f7f-c461-4256-b602-75244ca60248  A Google user
# 117291  dc1352e9-10a8-41ca-ab23-05d045b08e90     suraj soni
#
#                                                   content  score  \
# 117287  i really like it! there are so many movies and...      5
# 117288   I love Netflix. I always enjoy my time using it.      5
# 117289               Sound quality is very slow of movies      1
# 117290  Rate is very expensive.. bcos we see netflix s...      1
# 117291  this app is awesome for english movies ,series...      4
#
#         thumbsUpCount   reviewCreatedVersion                   at  \
# 117287              0                    NaN  2019-08-03 15:06:03
# 117288              0   8.34.0 build 4 50250  2022-08-15 16:16:30
# 117289              0                    NaN  2020-08-17 07:26:58
# 117290              0  7.17.0 build 13 34346  2019-07-21 09:41:42
# 117291              0                    NaN  2020-05-24 11:04:08
#
#                    appVersion
# 117287                    NaN
# 117288   8.34.0 build 4 50250
# 117289                    NaN
# 117290  7.17.0 build 13 34346
# 117291                    NaN
#
# 컬럼명:
#  Index(['reviewId', 'userName', 'content', 'score', 'thumbsUpCount',
#        'reviewCreatedVersion', 'at', 'appVersion'],
#       dtype='object')
#
# 데이터프레임의 shape (117292, 8)

# %%
import re
# 전처리 함수
def preprocess_text(text):
    if isinstance(text, float):
        return ""
    text = text.lower()  # 대문자를 소문자로
    text = re.sub(r'[^\w\s]', '', text)  # 구두점 제거
    text = re.sub(r'\d+', '', text)  # 숫자 제거
    text = text.strip()  # 띄어쓰기 제외하고 빈 칸 제거
    return text

# %%
df["preproces_content"] = df['content'].apply(preprocess_text)

# %%
df.head()
# Out:
#                                reviewId               userName  \
# 0  65ae4898-8007-47e3-92cd-ba06eac04574  Moosa Sam (Moosa Sam)
# 1  3cc99dd8-81f1-47ce-8b78-18c29719a941           PixEndstar53
# 2  1c639697-a825-4f11-b966-3e7cfb6eb292             JanCan1 GK
# 3  240cfd35-f94d-42d6-b145-154097dd2ce0           Brother Bear
# 4  c568b9f0-7b52-4dad-9b89-f57882014138              Riya Adak
#
#                                              content  score  thumbsUpCount  \
# 0  This App Not Supporting My Device ROG3 Mobile!...      1              0
# 1  I'm getting very tired, you guys keep logging ...      2              0
# 2  One of my go to channels..l was at least 4 mov...      5              0
# 3                      Poor scripts, Violent content      2              0
# 4                                               Good      3              0
#
#      reviewCreatedVersion                   at              appVersion  \
# 0   8.137.0 build 4 50942  2024-10-23 13:47:33   8.137.0 build 4 50942
# 1   8.137.0 build 4 50942  2024-10-23 13:27:18   8.137.0 build 4 50942
# 2  8.132.2 build 18 50846  2024-10-23 13:26:51  8.132.2 build 18 50846
# 3                     NaN  2024-10-23 13:19:59                     NaN
# 4   8.137.0 build 4 50942  2024-10-23 13:16:59   8.137.0 build 4 50942
#
#                                    preproces_content
# 0  this app not supporting my device rog mobile k...
# 1  im getting very tired you guys keep logging me...
# 2  one of my go to channelsl was at least  movies...
# 3                       poor scripts violent content
# 4                                               good

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\kjml\anaconda\envs\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
리뷰데이터 = df['score'].value_counts().reset_index()
리뷰데이터.columns = ['score', 'count']  # 열 이름 변경

# %%
sns.barplot(x='score', y='count', data=리뷰데이터)
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('Distribution of Scores')
plt.show()

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c pytorch torchtext
# Out:
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update torchtext
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - pytorch
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pytorch torchvision torchaudio torchtext -c pytorch
# Out:
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show torchtext
# Out:
# Name: torchtext
# Version: 0.18.0
# Summary: Text utilities, models, transforms, and datasets for PyTorch.
# Home-page: https://github.com/pytorch/text
# Author: PyTorch Text Team
# Author-email: packages@pytorch.org
# License: BSD
# Location: d:\kjml\anaconda\envs\myenv\Lib\site-packages
# Requires: numpy, requests, torch, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade torchtext
# Out:
# Requirement already satisfied: torchtext in d:\kjml\anaconda\envs\myenv\lib\site-packages (0.18.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tqdm in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (4.66.5)
# Requirement already satisfied: requests in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (2.5.0)
# Requirement already satisfied: numpy in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (4.11.0)
# Requirement already satisfied: setuptools in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (1.13.1)
# Requirement already satisfied: networkx in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.3)
# Requirement already satisfied: jinja2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from sympy==1.13.1->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from jinja2->torch>=2.3.0->torchtext) (2.1.3)

# %%
pip install torch torchtext --upgrade
# Out:
# Requirement already satisfied: torch in d:\kjml\anaconda\envs\myenv\lib\site-packages (2.5.0)
# Requirement already satisfied: torchtext in d:\kjml\anaconda\envs\myenv\lib\site-packages (0.18.0)
# Requirement already satisfied: filelock in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: setuptools in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: tqdm in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (4.66.5)
# Requirement already satisfied: requests in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: numpy in d:\kjml\anaconda\envs\myenv\lib\site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from requests->torchtext) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from tqdm->torchtext) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np


# 데이터셋 클래스 정의
class ReviewDataset(Dataset):
    def __init__(self, reviews, ratings, text_pipeline, label_pipeline):
        self.reviews = reviews
        self.ratings = ratings
        self.text_pipeline = text_pipeline
        self.label_pipeline = label_pipeline

    def __len__(self):
        return len(self.reviews)

    def __getitem__(self, idx):
        review = self.text_pipeline(self.reviews[idx])
        rating = self.label_pipeline(self.ratings[idx])
        return torch.tensor(review), torch.tensor(rating)

# 데이터셋 정의
train_dataset = ReviewDataset(train_reviews, train_ratings, text_pipeline, label_pipeline)
test_dataset = ReviewDataset(test_reviews, test_ratings, text_pipeline, label_pipeline)

# 데이터 로더 정의
BATCH_SIZE = 64

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text):
        embedded = self.embedding(text)
        output, (hidden, cell) = self.lstm(embedded.unsqueeze(0))
        return self.fc(hidden[-1])

# 하이퍼파라미터 정의
VOCAB_SIZE = len(vocab)
EMBED_DIM = 64
HIDDEN_DIM = 128
OUTPUT_DIM = len(set(ratings))  # 예측할 점수 개수

# 모델 초기화
model = LSTMModel(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, OUTPUT_DIM)

# 손실 함수와 옵티마이저 정의
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 5
#       3 import torch.nn as nn
#       4 import torch.optim as optim
# ----> 5 from torchtext.data.utils import get_tokenizer
#       6 from torchtext.vocab import build_vocab_from_iterator
#       7 from torch.utils.data import DataLoader, Dataset
#
# ModuleNotFoundError: No module named 'torchtext'

# %%
# !pip install nltk textblob gensim


# 텍스트 전처리와 자연어 처리를 위한 라이브러리
import nltk
from textblob import TextBlob

# 토픽 모델링을 위한 라이브러리
import gensim
from gensim import corpora
from gensim.utils import simple_preprocess

# 감성 분석을 위한 함수
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity
# Out:
# Requirement already satisfied: nltk in d:\kjml\anaconda\envs\myenv\lib\site-packages (3.9.1)
# Requirement already satisfied: textblob in d:\kjml\anaconda\envs\myenv\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: gensim in d:\kjml\anaconda\envs\myenv\lib\site-packages (4.3.3)
# Requirement already satisfied: click in d:\kjml\anaconda\envs\myenv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\kjml\anaconda\envs\myenv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in d:\kjml\anaconda\envs\myenv\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\kjml\anaconda\envs\myenv\lib\site-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in d:\kjml\anaconda\envs\myenv\lib\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: colorama in c:\users\wotjr\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
df['sentiment'] = df["preproces_content"].apply(get_sentiment)  # (DIY) apply를 사용하여 감성 분석을 해보세요. 필수 텍스트가 전처리되어있어야 합니다.
# df에 sentiment 값을 적용을 먼저 하시고, 아래와 같이 긍정과 부정을 분류하세요.
df['sentiment_label'] = df['sentiment'].apply(lambda x: 'positive' if x > 0.1 else ('negative' if x < -0.1 else 'neutral'))

# %%
df[['preproces_content', 'score', 'sentiment_label']]
# Out:
#                                         preproces_content  score  \
# 0       this app not supporting my device rog mobile k...      1
# 1       im getting very tired you guys keep logging me...      2
# 2       one of my go to channelsl was at least  movies...      5
# 3                            poor scripts violent content      2
# 4                                                    good      3
# ...                                                   ...    ...
# 117287  i really like it there are so many movies and ...      5
# 117288     i love netflix i always enjoy my time using it      5
# 117289               sound quality is very slow of movies      1
# 117290  rate is very expensive bcos we see netflix sun...      1
# 117291  this app is awesome for english movies series ...      4
#
#        sentiment_label
# 0             positive
# 1             negative
# 2              neutral
# 3             negative
# 4             positive
# ...                ...
# 117287        positive
# 117288        positive
# 117289         neutral
# 117290        negative
# 117291        positive
#
# [117292 rows x 3 columns]

# %%
df
# Out:
#                                     reviewId               userName  \
# 0       65ae4898-8007-47e3-92cd-ba06eac04574  Moosa Sam (Moosa Sam)
# 1       3cc99dd8-81f1-47ce-8b78-18c29719a941           PixEndstar53
# 2       1c639697-a825-4f11-b966-3e7cfb6eb292             JanCan1 GK
# 3       240cfd35-f94d-42d6-b145-154097dd2ce0           Brother Bear
# 4       c568b9f0-7b52-4dad-9b89-f57882014138              Riya Adak
# ...                                      ...                    ...
# 117287  a760ead9-e7aa-4ed1-a651-5c37c3600dac          A Google user
# 117288  4957f9e7-d7f4-4a52-9764-031cebcac83f           Captain Jeoy
# 117289  9acf7586-7abf-4b50-8c50-3ede3b2a42c4               Suryansh
# 117290  32870f7f-c461-4256-b602-75244ca60248          A Google user
# 117291  dc1352e9-10a8-41ca-ab23-05d045b08e90             suraj soni
#
#                                                   content  score  \
# 0       This App Not Supporting My Device ROG3 Mobile!...      1
# 1       I'm getting very tired, you guys keep logging ...      2
# 2       One of my go to channels..l was at least 4 mov...      5
# 3                           Poor scripts, Violent content      2
# 4                                                    Good      3
# ...                                                   ...    ...
# 117287  i really like it! there are so many movies and...      5
# 117288   I love Netflix. I always enjoy my time using it.      5
# 117289               Sound quality is very slow of movies      1
# 117290  Rate is very expensive.. bcos we see netflix s...      1
# 117291  this app is awesome for english movies ,series...      4
#
#         thumbsUpCount    reviewCreatedVersion                   at  \
# 0                   0   8.137.0 build 4 50942  2024-10-23 13:47:33
# 1                   0   8.137.0 build 4 50942  2024-10-23 13:27:18
# 2                   0  8.132.2 build 18 50846  2024-10-23 13:26:51
# 3                   0                     NaN  2024-10-23 13:19:59
# 4                   0   8.137.0 build 4 50942  2024-10-23 13:16:59
# ...               ...                     ...                  ...
# 117287              0                     NaN  2019-08-03 15:06:03
# 117288              0    8.34.0 build 4 50250  2022-08-15 16:16:30
# 117289              0                     NaN  2020-08-17 07:26:58
# 117290              0   7.17.0 build 13 34346  2019-07-21 09:41:42
# 117291              0                     NaN  2020-05-24 11:04:08
#
#                     appVersion  \
# 0        8.137.0 build 4 50942
# 1        8.137.0 build 4 50942
# 2       8.132.2 build 18 50846
# 3                          NaN
# 4        8.137.0 build 4 50942
# ...                        ...
# 117287                     NaN
# 117288    8.34.0 build 4 50250
# 117289                     NaN
# 117290   7.17.0 build 13 34346
# 117291                     NaN
#
#                                         preproces_content  sentiment  \
# 0       this app not supporting my device rog mobile k...      0.225
# 1       im getting very tired you guys keep logging me...     -0.194
# 2       one of my go to channelsl was at least  movies...      0.100
# 3                            poor scripts violent content     -0.600
# 4                                                    good      0.700
# ...                                                   ...        ...
# 117287  i really like it there are so many movies and ...      0.350
# 117288     i love netflix i always enjoy my time using it      0.450
# 117289               sound quality is very slow of movies      0.005
# 117290  rate is very expensive bcos we see netflix sun...     -0.325
# 117291  this app is awesome for english movies series ...      0.500
#
#        sentiment_label
# 0             positive
# 1             negative
# 2              neutral
# 3             negative
# 4             positive
# ...                ...
# 117287        positive
# 117288        positive
# 117289         neutral
# 117290        negative
# 117291        positive
#
# [117292 rows x 11 columns]
